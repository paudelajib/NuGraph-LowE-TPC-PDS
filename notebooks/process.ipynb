# %% [markdown]
# ### Set autoreloading
# This extension will automatically update with any changes to packages in real time

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Import packages
# We'll need the `pynuml` and `nugraph` packages

# %%
import pynuml
import nugraph as ng

# %% [markdown]
# ### Open HDF5 event file
#
# This file contains the low-level tables we need to process into graph objects

# %%
file = pynuml.io.File("h5_nugraph.h5")
#file = pynuml.io.File("merged_nugraph.evt.h5")

# %% [markdown]
# ### Create hit graph producer
#
# Create a class that can read input information and use it to generate graphs

# %%
semantic_labeller = pynuml.labels.StandardLabels()
event_labeller = pynuml.labels.FlavorLabels()
processor = pynuml.process.HitGraphProducer(
        file=file,
        semantic_labeller=semantic_labeller,
        event_labeller=event_labeller,
        label_vertex=True,
        label_position=False,
        lower_bound=1,
)

# %%
file.read_data(0, 10)
evts = iter(file.build_evt())

# %% [markdown]
# ## Configure plotting utility
# Instantiate the **pynuml** utility for plotting graph objects, which will allow us to visualise the graphs we create

# %%
name, data = processor(next(evts))
print(name, data)
# Out:
# r20000047_sr0_evt0 NuGraphData(
#   metadata={
#     run=20000047,
#     subrun=0,
#     event=0,
#   },
#   sp={ pos=[14, 3] },
#   hit={
#     plane=[40],
#     pos=[40, 2],
#     x=[40, 6],
#     id=[40],
#     y_semantic=[40],
#   },
#   evt={
#     num_nodes=1,
#     y=[1],
#     y_vtx=[1, 3],
#   },
#   particle-truth={ num_nodes=1 },
#   (hit, delaunay, hit)={ edge_index=[2, 216] },
#   (hit, delaunay-planar, hit)={ edge_index=[2, 180] },
#   (hit, nexus, sp)={ edge_index=[2, 42] },
#   (hit, in, evt)={ edge_index=[2, 40] },
#   (sp, in, evt)={ edge_index=[2, 14] },
#   (hit, cluster-truth, particle-truth)={ edge_index=[2, 31] }
# )

# %%
plot = pynuml.plot.GraphPlot(
    planes=('u', 'v', 'y'),
    classes=semantic_labeller.labels[:-1])

# %% [markdown]
# ### Load a buffer of input graphs
#
# For interactive testing, we can use `read_data` to load the first 100 events in the event file using the following syntax, which will return a list of events that we can use to initialise an iterator

# %% [markdown]
# ### Retrieve the next event
#
# This block retrieves an event from the buffer. Since we defined `evts` as an iterator over our 100 events, the following block can be executed multiple times, and each time it's executed, it will step to the next event in the buffer. After fetching an event, we pass it into the processor to create a graph. Not all events produce good graphs, so if the next event does not return a valid graph, the code will continue to fetch events until it finds the next event that produces a valid graph.

# %%
name, data = processor(next(evts))
skip = 0
while data is None:
    name, data = processor(next(evts))
    skip += 1
if skip > 0:
    print(f'skipped {skip} events that did not produce valid graphs.')

# %% [markdown]
# ### Visualise graph
#
# We can use the plotting utility to take a closer look at the graph we just produced.

# %%
fig = plot.plot(data, target='instance', how='true', filter='show')
fig
# Out:
# FigureWidget({
#     'data': [{'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b46d3269-5f81-4e46-823d-2c227b0b6cbf',
#               'x': {'bdata': 'AABeQwAAXUMAAF1DAABcQwAAIkM=', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': 'b56SRETFkkRRqY9Eya6PRCfQqEM=', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '34020984-7b70-42a8-89ab-4db30d747b28',
#               'x': {'bdata': 'AEBSRAAAUkQAwFBEAIBQRABAUEQ=', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'nLCPRLi3j0RNxZJEKrOSREekkkQ=', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1'],
#                                    ['diffuse', '-1']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '-1, diffuse',
#               'marker': {'color': '#FF97FF', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '-1, diffuse',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5336fc7a-dd85-42c6-9885-258dd86262d5',
#               'x': {'bdata': 'AIBKRABASkQAAEpEAEBJRAAASUQAwEhE', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'MqmPRD6zj0SVvo9EZq6SROTCkkRc1pJE', 'dtype': 'f4'},
#               'yaxis': 'y3'},
#              {'customdata': array([['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, shower',
#               'marker': {'color': '#FECB52', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '0, shower',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3de539f0-c611-46fb-95b7-e197a223908f',
#               'x': {'bdata': 'AAA1QwAANEMAADNDAAAyQwAAMUMAADBDAAAvQwAALkM=', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': 'lAhZRHeFWESNJVhEgnZXROIeV0SEWldEqElYRKQKWUQ=', 'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'customdata': array([['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, shower',
#               'marker': {'color': '#FECB52', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '0, shower',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '410d88ba-b985-4a67-b4f6-285ac19cee9d',
#               'x': {'bdata': 'AABnRADAZkQAgGZEAEBmRAAAZkQAwGVE', 'dtype': 'f4'},
#               'xaxis': 'x2',
#               'y': {'bdata': 'IIVYRKnmV0RcW1dEo/JXRHN1WESUolhE', 'dtype': 'f4'},
#               'yaxis': 'y2'},
#              {'customdata': array([['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0'],
#                                    ['shower', '0']], dtype=object),
#               'hovertemplate': ('instance truth=%{customdata[1]' ... '>drift=%{y:.1f}<extra></extra>'),
#               'legendgroup': '0, shower',
#               'marker': {'color': '#FECB52', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': '0, shower',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0682a90a-668e-4f97-9b0c-b8a75e357a89',
#               'x': {'bdata': 'AMBNRACATUQAQE1EAABNRADATEQAgExEAEBMRAAATEQAwEtE', 'dtype': 'f4'},
#               'xaxis': 'x3',
#               'y': {'bdata': 'bvVYRBXJWETfe1hEzyFYRF+UV0QHRFdEsH1XRJZGWESN3VhE', 'dtype': 'f4'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': 'y',
#                                 'x': 0.15999999999999998,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'showarrow': False,
#                                 'text': 'v',
#                                 'x': 0.49999999999999994,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'showarrow': False,
#                                 'text': 'u',
#                                 'x': 0.8399999999999999,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'legend': {'orientation': 'h',
#                           'title': {'text': 'instance truth, semantic truth'},
#                           'tracegroupgap': 0,
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.05,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'template': '...',
#                'title': {'automargin': True, 'text': 'True instance labels'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.31999999999999995], 'title': {'text': 'proj'}},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.33999999999999997, 0.6599999999999999], 'title': {'text': 'proj'}},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.6799999999999999, 0.9999999999999999], 'title': {'text': 'proj'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'drift'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'matches': 'y', 'showticklabels': False},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'matches': 'y', 'showticklabels': False}}
# })
